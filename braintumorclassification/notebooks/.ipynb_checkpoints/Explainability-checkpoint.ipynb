# %% [markdown]
# ### Import model and data

# %%
from tensorflow.keras.models import load_model
import numpy as np

model_path = "../models/ResNet50v2.h5"
model = load_model(model_path)
# Out:
# 2023-03-09 20:30:23.469142: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-09 20:30:28.493827: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.applications.vgg16 import VGG16

# %%
train_data_dir = '../raw_data/Training/'
test_data_dir = '../raw_data/Testing/'


train_ds, val_ds = image_dataset_from_directory(
  train_data_dir,
  labels = "inferred",
  label_mode = "categorical",
  seed=123,
  image_size=(255, 255),
  validation_split = 0.2,
  subset="both",
  color_mode = 'rgb',
  batch_size= 40)

# We define a second one for the test data

test_ds = image_dataset_from_directory(
  test_data_dir,
  labels = "inferred",
  label_mode = "categorical",
  seed=123,
  image_size=(255, 255),
  color_mode = 'rgb',
  batch_size= 40)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Using 1142 files for validation.
# Found 1311 files belonging to 4 classes.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_8 (Functional)        (None, 8, 8, 2048)        23587712
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 16)          294928
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 50)                51250
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_6 (Dense)             (None, 20)                1020
#
#  dropout_4 (Dropout)         (None, 20)                0
#
#  dense_7 (Dense)             (None, 4)                 84
#
# =================================================================
# Total params: 23,934,994
# Trainable params: 347,282
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
def get_image_from_dataset (dataset, batch_num, image_num):
    for images, labels in dataset.take(batch_num):
        numpy_image = images.numpy()[image_num]/255
        numpy_label = labels.numpy()[image_num]
    
    return (numpy_image, numpy_label)

# %%
def get_images_from_dataset (dataset, batch_num):
    for images, labels in dataset.take(batch_num):
        numpy_images = images.numpy()/255
        numpy_labels = labels.numpy()
    
    return (numpy_images, numpy_labels)

# %%
data = get_images_from_dataset(test_ds,5)
datapoint = get_image_from_dataset(test_ds, 15, 5)
datapoint = (np.expand_dims(datapoint[0], axis=0), np.expand_dims(datapoint[1], axis=0))

# %%
# # Load a sample image (or multiple ones)
IMAGE_PATH = '/Users/victorvoneisenhart-rothe/code/Victorvone/braintumorclassification/braintumorclassification/raw_data/Testing/pituitary/Te-pi_0011.jpg'
img = load_img(IMAGE_PATH, target_size=(255, 255))
img = img_to_array(img)/255
datapoint = (img, np.array([3]))
datapoint = (np.expand_dims(datapoint[0], axis=0), np.expand_dims(datapoint[1], axis=0))
# plt.imshow(img)
datapoint[1].shape
# Out:
# (1, 1)

# %%
plt.imshow(datapoint[0][0,:,:,:])

# %%
# print(datapoint[1])
np.round(model.predict(datapoint[0]),3)
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([[0.73 , 0.156, 0.045, 0.07 ]], dtype=float32)

# %%
model.evaluate(test_ds)
# Out:
#  1/33 [..............................] - ETA: 2:23 - loss: 0.3418 - accuracy: 0.9500

# %% [markdown]
# ### Activation visualization

# %%
from tf_explain.core.activations import ExtractActivations

ActViz = ExtractActivations()
grid = ActViz.explain(datapoint, model, layers_name='conv2d_2')
ActViz.save(grid, "../Visualizations/", "ActViz.png")
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# ### GradCam

# %%
from tf_explain.core.grad_cam import GradCAM

#Start explainer
gradcam = GradCAM()
grid = gradcam.explain(datapoint, model, class_index=3, layer_name='conv2d_2') 

gradcam.save(grid, "../Visualizations/", "grad_cam.png")

# %% [markdown]
# ### VanillaGradients

# %%
from tf_explain.core.vanilla_gradients import VanillaGradients

Vanillagrad = VanillaGradients()
grid = Vanillagrad.explain(datapoint, model, class_index=3) 

Vanillagrad.save(grid, "../Visualizations/", "VanillaGradient.png")
# Out:
# /var/folders/yg/kt4pdk955453dzxyb3ppm5200000gn/T/ipykernel_34807/2175733447.py:4: UserWarning: Unsupported model architecture for VanillaGradients. The last two layers of the model should be: a layer which computes class scores with no activation, followed by an activation layer.
#   grid = Vanillagrad.explain(datapoint, model, class_index=3)

# %% [markdown]
# ### Occlusion sensitivity map

# %%
from tf_explain.core.occlusion_sensitivity import OcclusionSensitivity

#Start explainer
occsens = OcclusionSensitivity()
grid = occsens.explain(datapoint, model, class_index=0, patch_size=5) 

occsens.save(grid, "../Visualizations/", "OcclusionSensitivity.png")
# Out:
# 82/82 [==============================] - 202s 2s/step
